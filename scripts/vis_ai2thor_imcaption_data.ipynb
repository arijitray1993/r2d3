# %%
import json
from PIL import Image  
import os
from matplotlib.pyplot import figure, imshow, axis
from matplotlib.image import imread

# %%
def showImagesHorizontally(list_of_files):
    fig = figure(figsize=(20,10))
    number_of_files = len(list_of_files)
    for i in range(number_of_files):
        a=fig.add_subplot(1,number_of_files,i+1)
        image = imread(list_of_files[i])
        imshow(image,cmap='Greys_r')
        axis('off')

# %%
# load data
data = json.load(open("/projectnb/ivc-ml/array/research/robotics/dreamworlds/custom_datasets/procThor/all_room_json_programs_ai2_train_room_captions_gtobjonly.json"))

# %%
program_text, house_json, cam_ind_to_position, all_imgs, all_objs, all_room_captions = data[58]

# %%
cam_ind_to_position
# Out:
# {'0': [{'x': 0.5, 'y': 0.9, 'z': 3.0},
#   {'x': 0.0, 'y': 21.541611235662902, 'z': 0.0}],
#  '1': [{'x': 0.25, 'y': 0.9, 'z': 10.0},
#   {'x': 0.0, 'y': 158.4583887643371, 'z': 0.0}],
#  '2': [{'x': 3.5, 'y': 0.9, 'z': 10.5},
#   {'x': 0.0, 'y': 225.0013272040556, 'z': 0.0}],
#  '3': [{'x': 2.75, 'y': 0.9, 'z': 8.25}, {'x': 0.0, 'y': 360.0, 'z': 0.0}],
#  '4': [{'x': 3.5, 'y': 0.9, 'z': 2.75},
#   {'x': 0.0, 'y': 326.88768147279825, 'z': 0.0}]}

# %%
# display all images in a row
all_img_paths = [os.path.join("/projectnb/ivc-ml/array/research/robotics/ProcTHOR", img) for img in all_imgs]
showImagesHorizontally(all_img_paths)

# %%
# print the corresponding captions
all_room_captions
# Out:
# ['The room appears to be a cozy and functional living space. A painting hangs on the wall, adding a touch of artistic flair to the room. A television is mounted on the wall, providing entertainment options for the occupants. A floor lamp provides ample lighting, creating a warm and inviting atmosphere. An armchair and a houseplant are placed in the room, adding to the comfort and aesthetic appeal. A dining table and chairs are situated near the center of the room, making it a suitable space for meals and gatherings. A bed is also present in the room, indicating that it serves as a multi-purpose living area. A baseball bat is placed in the room, suggesting that the occupants may have an interest in sports or recreational activities. Overall, the room feels like a comfortable and well-equipped living space that caters to various needs and interests.',
#  "The room appears to be a living and dining area, featuring a dining table surrounded by chairs, an armchair, and a television. There is also a floor lamp and a houseplant, adding a touch of warmth and coziness to the space. The presence of a painting on the wall enhances the room's aesthetic appeal. A baseball bat is also visible in the room, possibly indicating that the residents enjoy sports or have a collection of memorabilia. Overall, the room feels inviting and comfortable, with a mix of functional and decorative elements.",
#  'The room appears to be a cozy and comfortable living space, featuring a wooden floor and various pieces of furniture. There is a dining table surrounded by chairs, providing a place for meals and gatherings. A desk is also present in the room, offering a workspace for tasks and projects. A dresser and a bed can be seen, indicating that this room serves multiple purposes, such as sleeping and storage. A houseplant adds a touch of greenery to the space, while a baseball bat suggests that the occupants may enjoy sports or outdoor activities. Overall, the room feels inviting and functional, catering to the needs of its inhabitants.',
#  'The room appears to be a simple and minimalistic space, with a wooden floor and a wooden bed frame. The bed is positioned against the wall, and there is a chair placed nearby. A dining table can be seen in the room, possibly indicating that this space is used for both sleeping and dining. The presence of a baseball bat suggests that the occupant of the room might be interested in sports or recreational activities. Overall, the room feels like a cozy and functional living space, with a focus on simplicity and practicality.',
#  'The room appears to be a cozy and comfortable living space. The presence of a painting on the wall adds a touch of artistic flair to the room. A television is mounted on the wall, providing entertainment for the occupants. A floor lamp provides ample lighting, creating a warm and inviting atmosphere. A dining table is situated in the room, offering a place for meals and gatherings. A bed is also present, indicating that the room serves multiple purposes, including sleeping quarters. A chair is placed near the dining table, and a houseplant adds a touch of nature to the space. A baseball bat is also visible, suggesting that the occupants may have an interest in sports or outdoor activities. Overall, the room feels like a welcoming and functional living area.']
