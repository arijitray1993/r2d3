# %%
import json
from IPython.display import Image

# %%
topdown_caption_data = json.load(open("/projectnb/ivc-ml/array/research/robotics/dreamworlds/custom_datasets/procThor/GPT4V_room_descriptions_topdown.json"))
        # else:
caption_data = json.load(open("/projectnb/ivc-ml/array/research/robotics/dreamworlds/custom_datasets/procThor/GPT4V_room_descriptions.json"))

# %%
entry = topdown_caption_data[67]

# %%
Image(filename=entry[1])

# %%
entry[2]
# Out:
# "In the top-down view of the room, the bed is centrally placed towards the top, with some items on it such as a clock, book, and decorative vase. Below the bed and slightly to its left is a pet bed. Further down and slightly right from the pet bed, you'll find a basketball. Directly below the bed, near the bottom of the room, is a dresser. To the right and above the dresser, there's a television set mounted on the wall. A piece of wall decor is near the bottom of the room, just to the right, and another piece of wall decor is on the right wall near the middle.\n\nThe atmosphere of the room suggests a personal and private space, possibly a bedroom with a comfortable and lived-in feel, equipped for relaxation, entertainment, and personal grooming."

# %%
cap_entry = caption_data[166]

# %%
Image(filename=cap_entry[1])

# %%
print(cap_entry[2])
# Out:
# Place a bed with blue covers partially visible at the foreground, occupying a central bottom area of the frame. To the right of the bed, position a dining table parallel with the bed's length, accompanied by a chair on the side closest to you. A dresser should be positioned against the wall, behind the chair and to the right of the table. On the wall above the dresser, affix a wall decor photo. To the left of the bed, situate a side table with a round top, near the corner where two walls meet. Rest a baseball bat with its handle on the floor, leaning against the side table. On the same wall as the side table but further away, hang a wall decor painting. All walls exhibit a brick texture.

# %%
asset_desc = json.load(open("/projectnb/ivc-ml/array/research/robotics/dreamworlds/custom_datasets/procThor/asset_descriptions.json"))

# %%
asset_entry = asset_desc[166]
